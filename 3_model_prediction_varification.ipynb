# %%
from keras import models
# Out:
# 2026-09-19 13:52:59.133729: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
best_accuracy_model = models.load_model('models_experiment_7(best)/weights.51-0.9977.keras')
best_loss_model = models.load_model('models_experiment_7(best)/weights.66-0.9972.keras')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789804429.364452  477150 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9718 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:05:00.0, compute capability: 8.6
